# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider

cloud_config= {
        'secure_connect_bundle': 'secure-connect-test.zip'
}
auth_provider = PlainTextAuthProvider('gHhezGBJmuWZBTuwHjqorjlI', 'oKmrrk3G57tFvFn-XOmPpQP5qlfz9bmNgdiQ914P1AgT0oQrKqu_XFyE,tClFHoMgFJS-XZIWutlrhH.2GD.cP,NMPIA_Mpik5fekLDu87Bjq9uyDDE3Y1iPkks5xkZJ')
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

row = session.execute("select release_version from system.local").one()
if row:
    print(row[0])
else:
    print("An error occurred.")
# Out:
# 4.0.0.6813

# %% [markdown]
# # CAP theoram
# ![image.png](attachment:image.png)
# - <b>consitent </b>:if you write data to the distributed system, you should be able to read the same data at any point in time from any nodes of the system or simply return an error if data is in an inconsistent state. Never return inconsistent data.
# - <b>available </b>:means the system should always perform reads/writes on any non-failing node of the cluster successfully without any error. This is availability is mainly associated with network partition. i.e. in the presence of network partition whether a node returns success response or an error for read/write operation.
# - <b>partition tolerant </b>:means, if there is a partition between nodes or the parts of the cluster in a distributed system are not able to talk to each other, the system should still be functioning
