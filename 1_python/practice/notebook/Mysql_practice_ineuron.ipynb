# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host = "localhost",user="root",passwd="root",use_pure=True)
    query = "SHOW DATABASES"
    cursor = mydb.cursor() # create cursor to excute the query
    cursor.execute(query)
    print([i for i in cursor.fetchall()])
    
except:
    print("connection not aquired")
finally:
    mydb.close()
# Out:
# [('information_schema',), ('mysql',), ('performance_schema',), ('sakila',), ('sarvesh',), ('sys',), ('world',)]

# %% [markdown]
# ## create database

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host = "localhost",user="root",passwd="root",use_pure=True)
    query = "create database if not exists sarvesh".upper()
    cursor = mydb.cursor() # create cursor to excute the query
    cursor.execute(query)
    
    
except Exception as e:
    print(e)
    print("connection not aquired")

# %% [markdown]
# ## create table

# %%
import mysql.connector as connection

try:
    ## add database parameter to to connect particular database
    mydb = connection.connect(host = "localhost",database = "sarvesh",user="root",passwd="root",use_pure=True)
    query = "create table IF NOT EXISTS test(x1 INT(5),x2 VARCHAR(20),x3 DATE)".upper()
    cursor = mydb.cursor() # create cursor to excute the query
    cursor.execute(query)
    
    
except Exception as e:
    print(e)
    print("connection not aquired") 
else:
    print('table created!')
# Out:
# table created!

# %% [markdown]
# ### Insert into table created

# %%
import mysql.connector as connection

try:
    ## add database parameter to to connect particular database
    mydb = connection.connect(host="localhost",
                              database="sarvesh",
                              user="root",
                              passwd="root",
                              use_pure=True)
    query = "insert into test values('1111','Sarvesh A','2021-05-16')".upper(
    )  # yyyy-mm-dd
    cursor = mydb.cursor()  # create cursor to excute the query
    cursor.execute(query)
    
except Exception as e:
    print(e)
    print("connection not aquired")
else:
    print('value inserted!')
    mydb.commit()
# Out:
# value inserted!

# %%
cursor.execute('select * from test')
print(cursor.fetchall())
# Out:
# [(1112, 'AKSHAY B', datetime.date(2021, 5, 16)), (1111, 'SARVESH A', datetime.date(2021, 5, 16))]

# %%
print(cursor.fetchall())
# Out:
# [(1112, 'AKSHAY B', datetime.date(2021, 5, 16)), (1111, 'SARVESH A', datetime.date(2021, 5, 16))]

# %% [markdown]
# ### using pandas for csv

# %%
import pandas as pd
df = pd.read_sql("select * from test",mydb,columns=None)

# %%
cursor.execute("create table if not exists test1( x1 INT(5), x2 varchar(20), x3 DATE);")

# %%
df.to_sql('test1',mydb)

# %%
import csv
with open('carbon_nanotubes.csv') as f:
    with open('cleaned_carbon_nanotubes.csv', 'w') as csv_clean:
        csv = csv.writer(csv_clean,delimiter=',')
        for i in f.readlines():
            i=i.replace(';', ',').split(',')
            print(len(i))
            csv.writerow(i)
# Out:
# 8
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# ...

# %%
import mysql.connector as connection
try:
    mydb = connection.connect(host='localhost',
                              user='root',
                              passwd='root',
                              database='sarvesh')
    cursor = mydb.cursor()

except Exception as e:
    print('something went wrong')
    print(e)
else:
    query = 'drop table IF EXISTS EDdata'
    cursor.execute(query)
    query = "create table EDdata(MRN INT(100),presentation_visit_no INT(255),Triage_priority INT(2),Age INT(3),Arrival_date DATETIME,dr_seen_date DATETIME,Depart_actual_date DATETIME,depart_status_code varchar(100),departure_statue_desc varchar(255),depart_dest_code varchar(255),depart_dest_desc varchar(255),TimeDiff_Arrival_Actual_Depart INT(5),TimeDiff_treatDrNr_Act_Depart INT(5),presenting_complaint_code INT(10),Presenting_complaint_desc varchar(255),diag_code varchar(100),diagnosis_desc varchar(100));"
    
    cursor.execute(query)
    print('all good')
# Out:
# all good

# %%
import pandas as pd 
df = pd.read_excel('./data/Data Challenge-Generic ED 2009.xlsx',engine = 'openpyxl')
# Out:
# 0   2009-01-01 00:17:00
# 1   2009-01-01 00:35:00
# 2   2009-01-01 00:55:00
# 3   2009-01-01 03:22:00
# 4   2009-01-01 03:55:00
# Name: Arrival Date, dtype: datetime64[ns]

# %%
import mysql.connector as connection
import pandas as pd 
from tqdm import tqdm
df = pd.read_excel('./data/Data Challenge-Generic ED 2009.xlsx',engine = 'openpyxl')
try:
    mydb = connection.connect(host='localhost',
                              user='root',
                              passwd='root',
                              database='sarvesh')
    cursor = mydb.cursor()
    df['Arrival Date'] = [str(i).split('T')[0] for i in df['Arrival Date'].values][0]
    df['Dr Seen Date'] = [str(i).split('T')[0] for i in df['Dr Seen Date'].values][0]
    df['Depart Actual Date'] = [str(i).split('T')[0] for i in df['Dr Seen Date'].values][0]
    for index,row in tqdm(df.iterrows()):
        query = "insert into EDdata(MRN ,presentation_visit_no ,Triage_priority ,Age ,Arrival_date ,dr_seen_date ,Depart_actual_date ,depart_status_code ,departure_statue_desc ,depart_dest_code ,depart_dest_desc ,TimeDiff_Arrival_Actual_Depart ,TimeDiff_treatDrNr_Act_Depart ,presenting_complaint_code ,Presenting_complaint_desc ,diag_code ,diagnosis_desc) values('{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}');".format(*[row[i] for i in ['MRN', 'Presentation Visit Number', 'Triage Priority', ' Age  (yrs)',
           'Arrival Date', 'Dr Seen Date', 'Depart Actual Date',
           'Depart Status Code', 'Departure Status Desc.', 'Depart. Dest. Code',
           'Depart. Dest. Desc.', 'TimeDiff Arrival-Actual Depart (mins)',
           'TimeDiff TreatDrNr-Act. Depart (mins)', 'Presenting Complaint Code',
           'Presenting Complaint Desc.', 'Diag Code', 'Diagnosis Desc.']])
        try:
            cursor.execute(query)
        except:
            continue
        
        mydb.commit()
        
    

except Exception as e:
    print('something went wrong')
    print(query)
    print(e)
else:
    
    #     cursor.execute(query)
    mydb.commit()
    print('all good')

# %%
date = [str(i).split('T') for i in df['Arrival Date'].values]

# %%
for index,row in df.iterrows():
        query = "insert into EDdata(MRN ,presentation_visit_no ,Triage_priority ,Age ,Arrival_date ,dr_seen_date ,Depart_actual_date ,depart_status_code ,departure_statue_desc ,depart_dest_code ,depart_dest_desc ,TimeDiff_Arrival_Actual_Depart ,TimeDiff_treatDrNr_Act_Depart ,presenting_complaint_code ,Presenting_complaint_desc ,diag_code ,diagnosis_desc) values('{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}','{}');".format(*[row[i] for i in ['MRN', 'Presentation Visit Number', 'Triage Priority', ' Age  (yrs)',
           'Arrival Date', 'Dr Seen Date', 'Depart Actual Date',
           'Depart Status Code', 'Departure Status Desc.', 'Depart. Dest. Code',
           'Depart. Dest. Desc.', 'TimeDiff Arrival-Actual Depart (mins)',
           'TimeDiff TreatDrNr-Act. Depart (mins)', 'Presenting Complaint Code',
           'Presenting Complaint Desc.', 'Diag Code', 'Diagnosis Desc.']])
        print(query)
        break
# Out:
# insert into EDdata(MRN ,presentation_visit_no ,Triage_priority ,Age ,Arrival_date ,dr_seen_date ,Depart_actual_date ,depart_status_code ,departure_statue_desc ,depart_dest_code ,depart_dest_desc ,TimeDiff_Arrival_Actual_Depart ,TimeDiff_treatDrNr_Act_Depart ,presenting_complaint_code ,Presenting_complaint_desc ,diag_code ,diagnosis_desc) values('67269','63190','3','15','2009-01-01 00:17:00','2009-01-01 02:11:00','2009-01-01 12:30:00','H','ED SERVICE EVENT COMPLETED - DISCHARGED','DISCH','* DISCHARGED','733','619.0','4000.0','DRUG / ALCOHOL / POISONING','F43.9','EMOTIONAL CRISIS');

# %%
import pandas as pd 
import datetime
df = pd.read_excel('./data/Data Challenge-Generic ED 2009.xlsx',engine = 'openpyxl')
print(df['Arrival Date'].unique())
df['Arrival Date'] = [str(i).split('T')[0] for i in df['Arrival Date'].values][0]
df['Arrival Date'].unique()
# Out:
# <class 'numpy.ndarray'>
# array(['2009-01-01'], dtype=object)

# %%
df['Arrival Date']
# Out:
# 0        2009-01-01
# 1        2009-01-01
# 2        2009-01-01
# 3        2009-01-01
# 4        2009-01-01
#             ...
# 30183    2009-01-01
# 30184    2009-01-01
# 30185    2009-01-01
# 30186    2009-01-01
# 30187    2009-01-01
# Name: Arrival Date, Length: 30188, dtype: object

# %%
import mysql.connector as connector
try:
    mydb = connector.connect(host = 'localhost',user = 'root',passwd='root',database = 'sarvesh')
    cursor = mydb.cursor()
    query = 'select age from eddata where age not between 1 and 15 order by mrn DESC limit 10;'
    query = 'select count(mrn),age from eddata group by age having count(age)>1500 order by count(age) Desc limit 2'
#     query = 'select max(mrn) from eddata'
    cursor.execute(query)
    for i in cursor.fetchall():
        print(i)
except Exception as e:
    print(e)
# Out:
# (4638, 0)
# (4146, 1)

# %%
# !pip install cryptography

# %%
from cryptography.fernet import Fernet
# Put this somewhere safe!
key = Fernet.generate_key()
print(key)
f = Fernet(key)
token = f.encrypt(b"A really secret message. Not for prying eyes.")
print(token)

print(f.decrypt(token))
'A really secret message. Not for prying eyes.'
# Out:
# b'AcqkUTO5D45MJV0IM6y8UX0FtPJWD4YstOIS_IEPU4w='
# b'gAAAAABgqj0IQF1TZBdNSOmI1uEtXibTr-SZHVDTh4bRgK4glERxNQQ9j3eiQuZl7mUV0HymY1xILAbZKMGiHVmNay56KKD46s0tQZWvdYQxBMJxi4moYTZZoKtil5zNYIA3Aw2e66RP'
# b'A really secret message. Not for prying eyes.'
# 'A really secret message. Not for prying eyes.'
